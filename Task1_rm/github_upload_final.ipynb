# %%
# encoding is a way to convert human readable language into binary numbers for  omputer to understsnd
# UTF-8 is a variable-length encoding that uses 1 to 4 bytes (not 8 bytes) to represent a character in the Unicode character set.
# each byte in utf8 is 8 bits ex for A-01000001
# The Euro symbol (€) uses 3 bytes: 11100010 10000010 10101100
# when we see how the encoding is from utf8 to bytes 
# If you look at a bytes object, you'll see that it has a b in front of it, 
# and then maybe some text after. That's because bytes are printed out as if 
# they were characters encoded in ASCII. (ASCII is an older character encoding 
# that doesn't really work for writing any language other than English.) 
# We can also run into trouble if we try to use the wrong encoding to map from a string to bytes.
# Like I said earlier, strings are UTF-8 by default in Python 3, 
# so if we try to treat them like they were in another encoding we'll create problem


# our strings in python are by defualt in utf-8 encoding ,if we try to encode them into a different encoding for ex-ascii ,
# then the characters same in ascii will be only available where as the unknown characters wont be available and we dont have a method to decode back the unknown characters to original string
# ex-
# # start with a string
# before = "This is the euro symbol: €"

# # encode it to a different encoding, replacing characters that raise errors
# after = before.encode("ascii", errors = "replace")

# # convert it back to utf-8
# print(after.decode("ascii"))

# # We've lost the original underlying byte string! It's been 
# # replaced with the underlying byte string for the unknown character :(




import pandas as pd
import numpy as np
import seaborn as sns

# %%
# helpful character encoding module
import chardet
# which is used to detect the character encoding of text files or byte data.

#to check the encoding of a random file

# with open('example.txt', 'rb') as file:
#     raw_data = file.read()
#     result = chardet.detect(raw_data)
#     print(result)  # Outputs something like {'encoding': 'utf-8', 'confidence': 0.99}

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import chardet
before="this is japanese-你好"
after = before.encode("ascii", errors = "replace")
print (after)
print(after.decode("ascii"))
before="this is japanese-你好"
after = before.encode("UTF-8", errors = "replace")
print (after)
print(after.decode("UTF-8"))
# Out:
# b'this is japanese-??'
# this is japanese-??
# b'this is japanese-\xe4\xbd\xa0\xe5\xa5\xbd'
# this is japanese-你好

# %%
#reading in files with encoding problem
# we generally dont know the file is encoded in which form utf-8 or ascii intially so we consider some of the records of the starting and then 
# check which form is ot encoded in and then so on


with open("//Users//vanshpahwa//Downloads//ks-projects-201801.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))

# check what the character encoding might be
print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
with open("//Users//vanshpahwa//Downloads//ks-projects-201801.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))

# check what the character encoding might be
print(result)
# df = pd.read_csv('//Users//vanshpahwa//Downloads//ks-projects-201801.csv', encoding='Windows-1252')
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
df = pd.read_csv("//Users//vanshpahwa//Downloads//ks-projects-201801.csv", encoding='ISO-8859-1')
df
# look at the first few lines
df.head()
#encoding='ISO-8859-1' is a superset of encoding='Windows-1252'
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...
