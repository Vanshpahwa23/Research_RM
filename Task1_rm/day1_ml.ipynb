# %%
import pandas as pd
df=pd.read_csv("//Users//vanshpahwa//Downloads//RM.AI.TASK1.CSV")
df
# Out:
# /var/folders/0w/4d7v1n1s7wd7n4dnv5f69jbh0000gn/T/ipykernel_50214/3056649465.py:2: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("//Users//vanshpahwa//Downloads//RM.AI.TASK1.CSV")
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0       2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1       2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2       2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3       2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4       2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# ...            ...         ...    ...  ...   ...    ...        ...       ...
# 407683  2017-12-31  2017123101     29    4   NaN  00:28          1      28.0
# 407684  2017-12-31  2017123101     29    4   3.0  00:28          1      28.0
# ...

# %%
df.head(5)
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# 2          37.0         PIT  ...       NaN     0.551088     0.448912
# 3          41.0         PIT  ... -5.031425     0.510793     0.489207
# 4           8.0         PIT  ...       NaN     0.461217     0.538783
#
#    Home_WP_post  Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# ...

# %%
df.sample(5)
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 310751  2015-12-20  2015122001     12    3   NaN  15:00         15    1800.0
# 385704  2017-11-06  2017110600      1    1   2.0  13:08         14    3488.0
# 42593   2010-01-03  2010010307      5    1   1.0  01:03          2    2763.0
# 193501  2013-10-06  2013100610     19    4   NaN  04:24          5     264.0
# 390390  2017-11-19  2017111909      7    2   3.0  01:29          2    1889.0
#
#         PlayTimeDiff SideofField  ...  yacEPA  Home_WP_pre  Away_WP_pre  \
# 310751           0.0         ARI  ...     NaN     0.268719     0.731281
# 385704          34.0          GB  ...     NaN     0.526702     0.473298
# 42593           43.0         NYG  ...     NaN     0.836767     0.163233
# 193501           5.0         OAK  ...     NaN     0.637191     0.362809
# 390390          24.0          NE  ...     NaN     0.162024     0.837976
#
# ...

# %%
missing_values=df.isnull().sum()
missing_values
# Out:
# Date             0
# GameID           0
# Drive            0
# qtr              0
# down         61154
#              ...
# Win_Prob     25009
# WPA           5541
# airWPA      248501
# yacWPA      248762
# Season           0
# Length: 102, dtype: int64

# %%
import numpy as np
total_cells=np.product(df.shape)
print(total_cells)
total_missing=missing_values.sum()
print(total_missing)
print((total_missing/total_cells)*100)
# Out:
# 41584176
# 11505187
# 27.66722370547874

# %%
missing_values[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %%
df
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0       2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1       2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2       2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3       2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4       2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# ...            ...         ...    ...  ...   ...    ...        ...       ...
# 407683  2017-12-31  2017123101     29    4   NaN  00:28          1      28.0
# 407684  2017-12-31  2017123101     29    4   3.0  00:28          1      28.0
# 407685  2017-12-31  2017123101     29    4   4.0  00:24          1      24.0
# 407686  2017-12-31  2017123101     30    4   1.0  00:14          1      14.0
# 407687  2017-12-31  2017123101     30    4   NaN  00:00          0       0.0
#
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
df
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0       2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1       2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2       2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3       2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4       2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# ...            ...         ...    ...  ...   ...    ...        ...       ...
# 407683  2017-12-31  2017123101     29    4   NaN  00:28          1      28.0
# 407684  2017-12-31  2017123101     29    4   3.0  00:28          1      28.0
# 407685  2017-12-31  2017123101     29    4   4.0  00:24          1      24.0
# 407686  2017-12-31  2017123101     30    4   1.0  00:14          1      14.0
# 407687  2017-12-31  2017123101     30    4   NaN  00:00          0       0.0
#
# ...

# %%
#total columns =102
columns_afterdropping=df.dropna(axis=1)
columns_afterdropping
# Out:
#               Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0       2009-09-10  2009091000      1    1         15        0       0
# 1       2009-09-10  2009091000      1    1         15       10       5
# 2       2009-09-10  2009091000      1    1         15        5       2
# 3       2009-09-10  2009091000      1    1         14        8       2
# 4       2009-09-10  2009091000      1    1         14        8       2
# ...            ...         ...    ...  ...        ...      ...     ...
# 407683  2017-12-31  2017123101     29    4          1        0      -4
# 407684  2017-12-31  2017123101     29    4          1       14      -4
# 407685  2017-12-31  2017123101     29    4          1       14       9
# 407686  2017-12-31  2017123101     30    4          1       10      -1
# 407687  2017-12-31  2017123101     30    4          0        0      -1
#
#         PlayAttempted  Yards.Gained  sp  ...  AwayTeam  Timeout_Indicator  \
# ...

# %%
102-37
# Out:
# 65

# %%
#65 columns dropped

# %% [markdown]
# filling missing values

# %%
sample=df.head(10)
sample
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# 5  2009-09-10  2009091000      2    1   1.0  13:16         14    3496.0
# 6  2009-09-10  2009091000      2    1   2.0  12:40         13    3460.0
# 7  2009-09-10  2009091000      2    1   3.0  12:11         13    3431.0
# 8  2009-09-10  2009091000      2    1   4.0  11:34         12    3394.0
# 9  2009-09-10  2009091000      3    1   1.0  11:24         12    3384.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# ...

# %%
sample.fillna(0)
# Out:
# /var/folders/0w/4d7v1n1s7wd7n4dnv5f69jbh0000gn/T/ipykernel_50214/804065099.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sample.fillna(0)
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   0.0  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
# 5  2009-09-10  2009091000      2    1   1.0  13:16         14    3496.0
# 6  2009-09-10  2009091000      2    1   2.0  12:40         13    3460.0
# ...

# %%
sample.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
# /var/folders/0w/4d7v1n1s7wd7n4dnv5f69jbh0000gn/T/ipykernel_50214/1536226847.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   sample.fillna(method = 'bfill', axis=0).fillna(0)
# /var/folders/0w/4d7v1n1s7wd7n4dnv5f69jbh0000gn/T/ipykernel_50214/1536226847.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sample.fillna(method = 'bfill', axis=0).fillna(0)
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   1.0  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[105], line 4
#       2 import numpy as np
#       3 from scipy import stats
# ----> 4 from mlxtend.preprocessing import minmax_scaling
#
# ModuleNotFoundError: No module named 'mlxtend'
